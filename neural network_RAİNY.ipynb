# %%
# -*- coding: utf-8 -*-

"""
Created on Wed Feb 23 13:17:51 2022

@author: Tuse
"""
#WORKING
#Neural Network - RAINY


import numpy as np # linear algebra
import pandas as pd # data processing
from sklearn.linear_model import LinearRegression
from keras.layers import Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn import metrics
from pandas import DataFrame,Series
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import matplotlib
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split,cross_val_score, cross_val_predict
import seaborn as sns # plotting library
from sklearn import svm
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU, SimpleRNN
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/rainy.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:, 1:12], df[:, 13:14]

x=np.asarray(x1).astype(np.float32)
y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.3, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(15, input_shape=(11,), activation='relu'))   #first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=200, batch_size=4, verbose=2, validation_split = 0.3, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

print(y_train)
print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#               t  Si        Ss      Xi       Xs     Xbh  Xba  Xp  So  Sno  \
# 0      0.000000  30  63.63455  58.476  224.352  31.425    0   0   0    0
# 1      0.010417  30  61.67313  58.459  224.324  31.420    0   0   0    0
# 2      0.020833  30  61.71973  53.069  224.373  30.827    0   0   0    0
# 3      0.031250  30  62.16018  51.462  220.973  30.270    0   0   0    0
# 4      0.041667  30  64.57526  49.730  217.740  29.719    0   0   0    0
# ...         ...  ..       ...     ...      ...     ...  ...  ..  ..  ...
# 1340  13.958333  30  75.62450  47.341  198.277  27.291    0   0   0    0
# 1341  13.968750  30  71.87255  46.476  200.320  27.422    0   0   0    0
# 1342  13.979167  30  69.45669  45.632  201.079  27.412    0   0   0    0
# 1343  13.989583  30  67.49915  44.469  200.958  27.270    0   0   0    0
# 1344  14.000000  30  63.63455  58.476  224.352  31.425    0   0   0    0
#
#            Snh      Snd       Xnd  Salk        Q
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#WORKING
#Neural Network- DATA

import statistics
import numpy as np # linear algebra
import pandas as pd # data processing
from sklearn.linear_model import LinearRegression
from keras.layers import Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn import metrics
from pandas import DataFrame,Series
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import matplotlib
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split,cross_val_score, cross_val_predict
import seaborn as sns # plotting library
from sklearn import svm
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU, SimpleRNN
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from statistics import mean


dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:, :-1], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.3, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(15, input_shape=(22,), activation='relu'))   #first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=200, batch_size=4, verbose=2, validation_split = 0.3, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
#var=statistics.variance(y_test)
#n=len(y_test)
#r= 1- (mse*n)/-var*(n-1)

#unexplained_error = tf.reduce_sum(tf.square(tf.sub(y, prediction)))
#total_error = tf.reduce_sum(tf.square(tf.sub(y, tf.reduce_mean(y))))
#r = tf.sub(1, tf.div(unexplained_error, total_error))
r2 = (1-(sum(yhat-y_train)**2)/sum(yhat-mean(y_train.tolist()))**2)
#r2=metrics.r_square.RSquare(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
#r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
#n=len(y_train)
#var=statistics.variance(y_train)
#r= 1- (mse*n)/-var
r2 = (1-(sum(yhat-y_train)**2)/sum(yhat-mean(y_train))**2)
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# 398           0.035223           0.222460           0.206619
#
#      0.574610352881628  0.656902819036000  0.709456824873330  \
# 0             0.570741           0.656903           0.727391
# 1             0.570741           0.659521           0.727391
# ...

# %%
import pandas as pd # data processing
import numpy as np


dataset=pd.read_excel(r'/content/drive/MyDrive/ML_Python/data.xlsx')
n=np.size(dataset)
print(n)
df = scaler.fit_transform(dataset)
x1, y1 = df[:, :-1], df[:, -1]

arr = np.array(x1)

#newarr = np.array_split(arr, 10)
newarr = np.array_split(y1, 400)
print(newarr)
# Out:
# 9177
# ...

# %%
print(x1)
# Out:
# [[0.96178412 0.687035   0.66463405 ... 0.97671011 0.90747216 0.28245825]
#  [0.96178412 0.68628976 0.66463405 ... 0.97671011 0.90747216 0.28245825]
#  [0.98089205 0.70417286 0.58275322 ... 0.97680157 0.90747216 0.28146713]
#  ...
#  [0.05095469 0.23397966 0.41202215 ... 0.99251074 0.70462588 0.10307212]
#  [0.04458558 0.23323441 0.41115056 ... 0.99260207 0.71174365 0.10208145]
#  [0.02547765 0.2146056  0.19860546 ... 0.99251074 0.71174365 0.10307212]]

# %%
#INPUT 18

import numpy as np # linear algebra
import pandas as pd # data processing
from sklearn.linear_model import LinearRegression
from keras.layers import Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn import metrics
from pandas import DataFrame,Series
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import matplotlib
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split,cross_val_score, cross_val_predict
import seaborn as sns # plotting library
from sklearn import svm
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU, SimpleRNN
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:,:-5], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing

x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.3, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model

his = tf.keras.callbacks.History()

model = Sequential()
model.add(Dense(15, input_shape=(18,), activation='relu')) #first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=200, batch_size=4, verbose=2, validation_split = 0.9, shuffle=True, callbacks=[his])

#hyperparameter tuning

model.summary()
his.history.keys() # dict_keys(['loss', 'categorical_accuracy'])

print(his.history['loss'])
# Out:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# 398           0.035223           0.222460           0.206619
#
#      0.574610352881628  0.656902819036000  0.709456824873330  \
# 0             0.570741           0.656903           0.727391
# 1             0.570741           0.659521           0.727391
# ...

# %%
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)

# %% [markdown]
# Changed the amount of input from 22 to 18. All errors increased.

# %%
#INPUT 8

dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:,:-15], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.3, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(15, input_shape=(8,), activation='relu')) #first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=200, batch_size=4, verbose=2, validation_split = 0.9, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# 398           0.035223           0.222460           0.206619
#
#      0.574610352881628  0.656902819036000  0.709456824873330  \
# 0             0.570741           0.656903           0.727391
# 1             0.570741           0.659521           0.727391
# ...

# %% [markdown]
# changed the amount of input to 8 all errors increase

# %%
#NN=50, EPO=400


dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:,:-1], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.3, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(50, input_shape=(22,), activation='relu')) #first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=400, batch_size=4, verbose=2, validation_split = 0.9, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# 398           0.035223           0.222460           0.206619
#
#      0.574610352881628  0.656902819036000  0.709456824873330  \
# 0             0.570741           0.656903           0.727391
# 1             0.570741           0.659521           0.727391
# ...

# %% [markdown]
# Epoch size changed to 400 and neuron numbers to 50 all errors increased compared to 400 epochs and 15 neurons. We were expecting them to not increase. Since we've increased the complexity of the code.

# %%
#NN=30, EPO=400


dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:,:-1], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.3, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(30, input_shape=(22,), activation='relu')) #first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=400, batch_size=4, verbose=2, validation_split = 0.9, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# 398           0.035223           0.222460           0.206619
#
#      0.574610352881628  0.656902819036000  0.709456824873330  \
# 0             0.570741           0.656903           0.727391
# 1             0.570741           0.659521           0.727391
# ...

# %% [markdown]
# ecpoch=400, number of neuron=30,all errors increased. that was unexpected,

# %%
#NN=30, EPO=100


dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:,:-1], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.3, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(30, input_shape=(22,), activation='relu')) #first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=100, batch_size=4, verbose=2, validation_split = 0.9, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# 398           0.035223           0.222460           0.206619
#
#      0.574610352881628  0.656902819036000  0.709456824873330  \
# 0             0.570741           0.656903           0.727391
# 1             0.570741           0.659521           0.727391
# ...

# %% [markdown]
# both with respect to the original errors and epo=100, errors increased

# %%
#NN=5, EPO=400


dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:,:-1], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.3, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(5, input_shape=(22,), activation='relu')) #first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=400, batch_size=4, verbose=2, validation_split = 0.9, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# 398           0.035223           0.222460           0.206619
#
#      0.574610352881628  0.656902819036000  0.709456824873330  \
# 0             0.570741           0.656903           0.727391
# 1             0.570741           0.659521           0.727391
# ...

# %% [markdown]
# epo=400, nneurons=5, all errors increased.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
from sklearn.linear_model import LinearRegression
from keras.layers import Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn import metrics
from pandas import DataFrame,Series
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import matplotlib
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split,cross_val_score, cross_val_predict
import seaborn as sns # plotting library
from sklearn import svm
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU, SimpleRNN
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:,:-1], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.3, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(10, input_shape=(22,), activation='relu')) #first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=400, batch_size=4, verbose=2, validation_split = 0.9, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# 398           0.035223           0.222460           0.206619
#
#      0.574610352881628  0.656902819036000  0.709456824873330  \
# 0             0.570741           0.656903           0.727391
# 1             0.570741           0.659521           0.727391
# ...

# %% [markdown]
# epoch=400, nneuron=10, all errors increased slighlty

# %%
#LAYER=2, EPO=400

dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:,:-1], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.3, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(15, input_shape=(22,), activation='relu'))
model.add(Dense(15, input_shape=(22,), activation='relu'))#first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=400, batch_size=4, verbose=2, validation_split = 0.9, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# 398           0.035223           0.222460           0.206619
#
#      0.574610352881628  0.656902819036000  0.709456824873330  \
# 0             0.570741           0.656903           0.727391
# 1             0.570741           0.659521           0.727391
# ...

# %% [markdown]
# epoch=400, layer=2, train error decreased slightly, test errors increased.

# %%
dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:,:-1], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.3, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(15, input_shape=(22,), activation='relu'))
model.add(Dense(15, input_shape=(22,), activation='relu'))
model.add(Dense(15, input_shape=(22,), activation='relu'))
model.add(Dense(15, input_shape=(22,), activation='relu'))
model.add(Dense(15, input_shape=(22,), activation='relu'))

#first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=400, batch_size=4, verbose=2, validation_split = 0.9, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# 398           0.035223           0.222460           0.206619
#
#      0.574610352881628  0.656902819036000  0.709456824873330  \
# 0             0.570741           0.656903           0.727391
# 1             0.570741           0.659521           0.727391
# ...

# %% [markdown]
# e=400, layer=5, all errors decreased.

# %%
#LAYER=10, EPO=400

dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:,:-1], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.3, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(15, input_shape=(22,), activation='relu'))
model.add(Dense(15, input_shape=(22,), activation='relu'))
model.add(Dense(15, input_shape=(22,), activation='relu'))
model.add(Dense(15, input_shape=(22,), activation='relu'))
model.add(Dense(15, input_shape=(22,), activation='relu'))
model.add(Dense(15, input_shape=(22,), activation='relu'))
model.add(Dense(15, input_shape=(22,), activation='relu'))
model.add(Dense(15, input_shape=(22,), activation='relu'))
model.add(Dense(15, input_shape=(22,), activation='relu'))
model.add(Dense(15, input_shape=(22,), activation='relu'))
#first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=400, batch_size=4, verbose=2, validation_split = 0.9, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# 398           0.035223           0.222460           0.206619
#
#      0.574610352881628  0.656902819036000  0.709456824873330  \
# 0             0.570741           0.656903           0.727391
# 1             0.570741           0.659521           0.727391
# ...

# %% [markdown]
# epo=400, layer=10 all errors decreased

# %%
#18 input, 400 epo
dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:,:-5], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.3, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(15, input_shape=(18,), activation='relu')) #first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=400, batch_size=4, verbose=2, validation_split = 0.9, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# 398           0.035223           0.222460           0.206619
#
#      0.574610352881628  0.656902819036000  0.709456824873330  \
# 0             0.570741           0.656903           0.727391
# 1             0.570741           0.659521           0.727391
# ...

# %% [markdown]
# input=18, epo=400, errors increased overfit?

# %%
#18 input, 100 epo
dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:,:-5], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.3, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(15, input_shape=(18,), activation='relu')) #first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=100, batch_size=4, verbose=2, validation_split = 0.9, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# 398           0.035223           0.222460           0.206619
#
#      0.574610352881628  0.656902819036000  0.709456824873330  \
# 0             0.570741           0.656903           0.727391
# 1             0.570741           0.659521           0.727391
# ...

# %% [markdown]
# input=18, epo=100, all errors increased, iki error arasındakiı fark çok az, thus can we say that epoch and number of inputs are independent.

# %%
dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:,:-1], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.1, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(15, input_shape=(22,), activation='relu')) #first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=400, batch_size=4, verbose=2, validation_split = 0.9, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# 398           0.035223           0.222460           0.206619
#
#      0.574610352881628  0.656902819036000  0.709456824873330  \
# 0             0.570741           0.656903           0.727391
# 1             0.570741           0.659521           0.727391
# ...

# %% [markdown]
# 0.1 test size, epo=400, train errors decreased test errors increased.

# %%
dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:,:-1], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.9, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(15, input_shape=(22,), activation='relu')) #first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=200, batch_size=4, verbose=2, validation_split = 0.5, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
# Exception ignored in: <function _xla_gc_callback at 0x7f292e4b9ea0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# ...

# %% [markdown]
# test size 0.5 epo=300, all errors increased.

# %%
dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:,:-1], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.5, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(10, input_shape=(22,), activation='relu')) #first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=200, batch_size=4, verbose=2, validation_split = 0.5, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# 398           0.035223           0.222460           0.206619
#
#      0.574610352881628  0.656902819036000  0.709456824873330  \
# 0             0.570741           0.656903           0.727391
# 1             0.570741           0.659521           0.727391
# ...

# %% [markdown]
# all errors increased withrespect to 0.5 test size, original

# %%
dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")
print(dataset)


#df1 = pd.read_excel('rainy.xlsx')
# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df
# split into input (X) and output (Y) variables
# split into input and output columns
x1, y1 = df[:,:-1], df[:, -1]

#x=np.asarray(x1).astype(np.float32)
#y=np.asarray(y1).astype(np.float32)

# Splitting the data for training and testing
x_train, x_test, y_train, y_test=train_test_split(x1,y1, test_size=0.5, random_state=1)   #30% test data, 70% training data

#print(x_train.shape)
#print(y_train.shape)


#print(x_train)
#print(y_train)

# define the keras model
model = Sequential()
model.add(Dense(30, input_shape=(22,), activation='relu')) #first layer has 15 neurons, dense = fully connected
model.add(Dense(1)) #second layer has 1 neuron, çıkış neuronu identity ile çarpılıyor, toolboztan dolayı böyle
model.compile(loss='mse', optimizer='sgd')   #mse=mean squared error

# fit the keras model on the training set
model.fit(x_train, y_train, epochs=200, batch_size=4, verbose=2, validation_split = 0.5, shuffle=True)

#hyperparameter tuning

model.summary()
# evaluate on test set
yhat = model.predict(x_test)
error = mean_squared_error(y_test, yhat)


#print('MSE: %.3f' % error)

test_set_predictions = model.predict(x_test)

mae=metrics.mean_absolute_error(y_test, test_set_predictions)
mse=metrics.mean_squared_error(y_test, test_set_predictions)
r2=metrics.r2_score(y_test, test_set_predictions)
# Printing the metrics
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

train_set_predictions = model.predict(x_train)

#print(y_train)
#print(train_set_predictions)

mae=metrics.mean_absolute_error(y_train, train_set_predictions)
mse=metrics.mean_squared_error(y_train, train_set_predictions)
r2=metrics.r2_score(y_train, train_set_predictions)    #function yaz
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#      0.968471711079010  0.689426862536875  0.669711834891515  \
# 0             0.962166           0.690165           0.667988
# 1             0.962166           0.689427           0.667988
# 2             0.981083           0.707131           0.586926
# 3             0.974777           0.707869           0.586926
# 4             0.974777           0.707131           0.586926
# ..                 ...                ...                ...
# 394           0.010000           0.181886           0.539496
# 395           0.060445           0.241640           0.418764
# 396           0.060445           0.241640           0.417902
# 397           0.054140           0.240902           0.417039
# 398           0.035223           0.222460           0.206619
#
#      0.574610352881628  0.656902819036000  0.709456824873330  \
# 0             0.570741           0.656903           0.727391
# 1             0.570741           0.659521           0.727391
# ...

# %% [markdown]
# neuron=30, test size=0.5 all errors increased

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Feb 23 13:54:32 2022

@author: Tuse
"""
#support vector regressor
#NOT WORKING

import numpy as np # linear algebra
import pandas as pd # data processing
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn import metrics
from pandas import DataFrame,Series
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import matplotlib
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split,cross_val_score, cross_val_predict
import seaborn as sns # plotting library
from sklearn import svm


df = pd.read_excel(r"/content/drive/MyDrive/ML_Python/rainy.xlsx")
#print(df.shape)
# summarize first few lines
print(df.head())
dataset = df.values
# split into input (X) and output (Y) variables
# split into input and output columns
x, y = df.values[:, 1:12], df.values[:, 13:14]



# Splitting the data for training and testing
# split data into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=1)

from sklearn.svm import SVR
regressor= SVR(kernel='rbf')
regressor.fit(x_train,y_train)
y_pred_svm=regressor.predict(x_test)
#y_pred_svm = cross_val_predict(regressor, x, y)
mae=metrics.mean_absolute_error(y_test, y_pred_svm)
mse=metrics.mean_squared_error(y_test, y_pred_svm)
r2=metrics.r2_score(y_test, y_pred_svm)
# Printing the metrics
print('Suppport Vector Regression Accuracy: ', regressor.score(x_test,y_test))
print('Test R2 square:',r2)
print('Test MAE: ', mae)
print('Test MSE: ', mse)

#Prediction using training set
y_pred_svm = regressor.predict(x_train)
mae=metrics.mean_absolute_error(y_train, y_pred_svm)
mse=metrics.mean_squared_error(y_train, y_pred_svm)
r2=metrics.r2_score(y_train, y_pred_svm)
# Printing the metrics
print('Train R2 square:',r2)
print('Train MAE: ', mae)
print('Train MSE: ', mse)
# Out:
#           t  Si        Ss      Xi       Xs     Xbh  Xba  Xp  So  Sno  \
# 0  0.000000  30  63.63455  58.476  224.352  31.425    0   0   0    0
# 1  0.010417  30  61.67313  58.459  224.324  31.420    0   0   0    0
# 2  0.020833  30  61.71973  53.069  224.373  30.827    0   0   0    0
# 3  0.031250  30  62.16018  51.462  220.973  30.270    0   0   0    0
# 4  0.041667  30  64.57526  49.730  217.740  29.719    0   0   0    0
#
#         Snh      Snd     Xnd  Salk        Q
# 0  30.24762  6.36346  11.814     7  21477.0
# 1  30.21283  6.16731  11.812     7  21474.0
# 2  31.04771  6.17197  11.589     7  19620.0
# 3  31.67387  6.21602  11.380     7  19334.0
# 4  33.15925  6.45753  11.172     7  18978.0
# Suppport Vector Regression Accuracy:  1.0
# Test R2 square: 1.0
# Test MAE:  0.0
# Test MSE:  0.0
# Train R2 square: 1.0
# Train MAE:  0.0
# Train MSE:  0.0
# ...
