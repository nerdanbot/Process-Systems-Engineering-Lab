# %%
import numpy as np # linear algebra
import pandas as pd # data processing
from sklearn.linear_model import LinearRegression
from keras.layers import Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn import metrics
from pandas import DataFrame,Series
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import matplotlib
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split,cross_val_score, cross_val_predict
import seaborn as sns # plotting library
from sklearn import svm
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU, SimpleRNN
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from statistics import mean


dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")




# summarize first few lines

scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df

# %% [markdown]
# # Yeni Bölüm

# %%
#10 fold

testmse=[]
trainmse=[]
los=[]

def optimizer(x_training,y_training,x_test, y_test):

  # define the keras model
  model = Sequential()
  model.add(Dense(100, input_shape=(22,), activation='relu'))
  model.add(Dense(1))

  #model.compile(loss='mse', optimizer='sgd')


  his = tf.keras.callbacks.History()

  # fit the keras model on the training set
  model.compile(loss='mse', optimizer='sgd', metrics=['accuracy'])
  history = model.fit(x_training, y_training, epochs=200, batch_size=4, verbose=2, validation_split = 0.3, shuffle=False, callbacks=[his] )

  model.summary()

  yhat = model.predict(x_test)
  error = mean_squared_error(y_test, yhat)


  #print('MSE: %.3f' % error)

  test_set_predictions = model.predict(x_test)

  mae=metrics.mean_absolute_error(y_test, test_set_predictions)
  mse=metrics.mean_squared_error(y_test, test_set_predictions)
  testmse.append(mse)

  #r2 = (1-(sum(yhat-y_training)**2)/sum(yhat-mean(y_training.tolist()))**2)

  #print('Test R2 square:',r2)
  print('Test MAE: ', mae)
  print('Test MSE: ', mse)

  train_set_predictions = model.predict(x_training)

  mae=metrics.mean_absolute_error(y_training, train_set_predictions)
  mse=metrics.mean_squared_error(y_training, train_set_predictions)

  #r2 = (1-(sum(yhat-y_training)**2)/sum(yhat-mean(y_training))**2)
  #print('Train R2 square:',r2)
  print('Train MAE: ', mae)
  print('Train MSE: ', mse)


  trainmse.append(mse)


  his.history.keys() # dict_keys(['loss', 'categorical_accuracy'])
  loss=his.history['loss']

  los.append(loss)


for i in range(1,355,39):


  dataset=pd.DataFrame(dataset)
  dataset=dataset.iloc[:391 , :]

  training = dataset.drop(range(i,i+39))
  test = dataset.iloc[range(i,i+39), :]
  #training

  x_training= training.iloc[:, :-1]
  y_training= training.iloc[:, -1]
  x_test=test.iloc[:, :-1]
  y_test=test.iloc[:, -1]


  optimizer(x_training , y_training , x_test , y_test )

flat_los = [item for sublist in los for item in sublist]
testmean=mean(testmse)
trainmean=mean(trainmse)
losmean=mean(flat_los)
print(testmean)
print(trainmean)
print(losmean)



# normalize çıkar, plot yap , early stop yaz
#nourn sayısı layer sayısı, epoch , act func
#gaussian, grid , random search, bayesian
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cbd4f7bb06b4> in <cell line: 63>()
#      64
#      65
# ---> 66   dataset=pd.DataFrame(dataset)
#      67   dataset=dataset.iloc[:391 , :]
#      68
#
# NameError: name 'pd' is not defined

# %%
#4fold
dataset=pd.read_excel(r"/content/drive/MyDrive/ML_Python/data.xlsx")



scaler = MinMaxScaler()

df = scaler.fit_transform(dataset)

dataset = df


testmse=[]
trainmse=[]
los=[]

def optimizer(x_training,y_training,x_test, y_test):

  # define the keras model
  model = Sequential()
  model.add(Dense(100, input_shape=(22,), activation='relu'))
  model.add(Dense(1))

  #model.compile(loss='mse', optimizer='sgd')


  his = tf.keras.callbacks.History()

  # fit the keras model on the training set
  model.compile(loss='mse', optimizer='sgd', metrics=['accuracy'])
  history = model.fit(x_training, y_training, epochs=2, batch_size=4, verbose=2, validation_split = 0.3, shuffle=False, callbacks=[his] )

  model.summary()

  yhat = model.predict(x_test)
  error = mean_squared_error(y_test, yhat)


  #print('MSE: %.3f' % error)

  test_set_predictions = model.predict(x_test)

  mae=metrics.mean_absolute_error(y_test, test_set_predictions)
  mse=metrics.mean_squared_error(y_test, test_set_predictions)
  testmse.append(mse)

  #r2 = (1-(sum(yhat-y_training)**2)/sum(yhat-mean(y_training.tolist()))**2)

  #print('Test R2 square:',r2)
  print('Test MAE: ', mae)
  print('Test MSE: ', mse)

  train_set_predictions = model.predict(x_training)

  mae=metrics.mean_absolute_error(y_training, train_set_predictions)
  mse=metrics.mean_squared_error(y_training, train_set_predictions)

  #r2 = (1-(sum(yhat-y_training)**2)/sum(yhat-mean(y_training))**2)
  #print('Train R2 square:',r2)
  print('Train MAE: ', mae)
  print('Train MSE: ', mse)


  trainmse.append(mse)


  his.history.keys() # dict_keys(['loss', 'categorical_accuracy'])
  loss=his.history['loss']

  los.append(loss)


for i in range(1,300,99):


  dataset=pd.DataFrame(dataset)
  dataset=dataset.iloc[:397 , :]

  training = dataset.drop(range(i,i+99))
  test = dataset.iloc[range(i,i+99), :]
  #training

  x_training= training.iloc[:, :-1]
  y_training= training.iloc[:, -1]
  x_test=test.iloc[:, :-1]
  y_test=test.iloc[:, -1]


  optimizer(x_training , y_training , x_test , y_test )

flat_los = [item for sublist in los for item in sublist]
testmean=mean(testmse)
trainmean=mean(trainmse)
losmean=mean(flat_los)
print(testmean)
print(trainmean)
print(losmean)

# %%
dataset
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.961784  0.687035  0.664634  0.566405  0.653437  0.724638  0.235185
# 1    0.961784  0.686290  0.664634  0.566405  0.656082  0.724638  0.236111
# 2    0.980892  0.704173  0.582753  0.611328  0.436508  0.920291  0.232407
# 3    0.974523  0.704918  0.582753  0.613281  0.431216  0.920291  0.232407
# 4    0.974523  0.704173  0.582753  0.611328  0.436508  0.920291  0.232407
# ..        ...       ...       ...       ...       ...       ...       ...
# 384  0.063694  0.155738  0.223868  0.146484  0.579366  0.561594  0.009259
# 385  0.070063  0.155738  0.223868  0.146484  0.579366  0.568840  0.009259
# 386  0.038216  0.196722  0.403310  0.187498  0.730157  0.489131  0.042593
# 387  0.050955  0.195976  0.404182  0.187498  0.732800  0.496376  0.043519
# 388  0.044586  0.196722  0.405054  0.191407  0.732800  0.496376  0.043519
#
#            7         8         9   ...        13        14        15  \
# ...

# %%
training = dataset.drop(range(39,39+39))
test = dataset.iloc[range(39+39), :]

# %%
training
# Out:
#            0         1         2         3         4         5         6   \
# 0    0